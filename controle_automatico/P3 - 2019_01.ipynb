# %% [markdown]
# # <font color='green' style='font-size: 40px;'>QUESTÃO 1  </font> <hr style='border: 2px solid green;'>

# %% [markdown]
# Faça o diagrama de Bode para : $ G(s) = \frac{18s}{s^2+1.8s+9}$ no papel monolog.

# %% [markdown]
# ## Memória de cálculo e dúvidas <hr style='line: 2px solid white;'>

# %% [markdown]
# # <font color='green' style='font-size: 40px;'>QUESTÃO 2  </font> <hr style='border: 2px solid green;'>

# %% [markdown]
# Relacione o diagrama polar com a afirmação correspondente:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## <font color='green' style='font-size: 22px;'> (B) G(s) tem 3 polos e um é zero </font>

# %% [markdown]
# ## <font color='green' style='font-size: 22px;'> (C) G(s) tem 1 polo e um é zero. </font>

# %% [markdown]
# # <font color='green' style='font-size: 40px;'>QUESTÃO 3  </font> <hr style='border: 2px solid green;'>

# %% [markdown]
# Para que um sistema do tipo $ G(s) = \frac{18s}{s^2+1.8s+9}$ tenha uma margem de $45°$ e um erro ao degrau de 0.01, projete:

# %% [markdown]
# ## <font color='green' style='font-size: 22px;'> a) Um controlador de avanço de fase C(s). De C(s)G(s), determine a {1. margem de fase obtida e sua frequência}, a {2. margem de ganho e sua frequência}. Da função de transferência de malha fechada encontre o {3. ganho nas frequências baixas}, a {4. banda passante} e a {5. frequência de corte}.</font>

# %% [markdown]
# ## <font color='green' style='font-size: 22px;'> b) Um controlador avanço-atraso de fase. De C(s)G(s), determine: {1. margem de fase e sua frequência}, a {2. margem de ganho e sua frequência}. Da função de transferência de malha fechada encontre o {3. ganho nas frequências baixas}, a{4. banda passante} e a {5. frequência de corte}. </font>

# %% [markdown]
# ## <font color='green' style='font-size: 22px;'> c) Comparando os dois controladores, o que vocÊ pode afirmar sobre? </font>

# %% [markdown]
# ## Memória de cálculo e dúvidas <hr style='line: 2px solid white;'>
