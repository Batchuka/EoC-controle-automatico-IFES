# %% [markdown]
# # <font style='font-size: 40px;'> QUESTÃO 1 </font> <hr style='border: 2px solid'>

# %% [markdown]
# ## <font style='font-size: 20px;'> Função transferência média obtida experimentalmente  </font> <hr style='line: 2px solid;'>

# %% [markdown]
# A função de transferência média dos dados “a5.csv” :
#
# $$ G(s) = 1.3885 \cdot \frac{20.223}{s^2 + 3s + 20.223} $$

# %% [markdown]
# ## <font style='font-size: 20px;'> Simulação e interpretação de Bode </font> <hr style='line: 2px solid;'>

# %%
# CÓDIGO OMITIDO
# Out:
# → Informações obtidas numéricamente:
#    Margem de Ganho (dB)  Margem de Fase (graus)  \
# 0                   inf                43.14319
#
#    Frequência de Crossover (ω/seg)  Frequência de Fase Zero (ω/seg)
# 0                              NaN                         6.380678

# %% [markdown]
# Segundo Ogata (pag 427, cap 7):
#
#
#     "A margem de ganho de um sistema de primeira ou de segunda ordens é infinita, visto que os diagramas polares para esses sistemas não cruzam o eixo real negativo"
#
# Consequentemente não haverá frequência de crossover. Além disso, podemos ver na imagem abaixo que a margem de fase é realmente $\approx 45° $ e a frequência desse valor realmente está em torno de $6 \frac{\omega}{seg}$
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## <font style='font-size: 20px;'> Simulação e interpretação de Nyquist  </font> <hr style='line: 2px solid;'>

# %%
# CÓDIGO OMITIDO

# %% [markdown]
# O plot de Nyquist concorda perfeitamente com o diagrama de Bode. Segundo ele o sistema é do tipo 0, temos 2 polos e temos uma margem de fase de aproximadamente $45°$. Não importa o ganho, o gráfico não abraçará $-1$
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # <font style='font-size: 40px;'> QUESTÃO 2 </font> <hr style='border: 2px solid'>

# %% [markdown]
# ## <font style='font-size: 20px;'> Simulação para diversos ganhos  </font> <hr style='line: 2px solid;'>

# %% [markdown]
# Como dito na questão anterior, a margem de ganho é infinita. A única forma desse sistema se tornar instável é através da fase. Faremos o seguinte para mostrar isso, na simulação do plot de Nyquist abaixo, 3 plots são feitos, para ganhos 1, 10 e 100. Isso mostra o comportamento assinstótico.

# %%
# CÓDIGO OMITIDO

# %% [markdown]
# É possível ver o comportamento assintótico do plot de nyquist, ele entra com ângulo -180.

# %% [markdown]
# # <font style='font-size: 40px;'> QUESTÃO 3 </font> <hr style='border: 2px solid'>

# %% [markdown]
# ## <font style='font-size: 20px;'> Resumo dos dados experimentais </font> <hr style='line: 2px solid;'>

# %%
# CÓDIGO OMITIDO
# Out:
#                  Sobressinal  Coeficiente de Amortecimento (ζ)  \
# Média               0.330111                          0.334555
# Valor Máximo        0.394422                          0.402900
# Variação Máxima     0.064312                          0.068345
#
#                  Frequência Natural não Amortecida (ω_d)  \
# Média                                           4.778245
# Valor Máximo                                    7.445800
# Variação Máxima                                 2.667555
#
#                  Frequência Natural Amortecida (ω_n)     Ganho
# Média                                       4.497064  1.388502
# Valor Máximo                                6.981300  2.322430
# Variação Máxima                             2.484236  0.933928

# %% [markdown]
# Bom, para cada um desses valores máximos teremos funções de transferência diferentes. O que farei é o seguinte, vamos gerar 3 diagramas de Bode — que serão plotados juntamente do diagrama de Bode da função média — e três plots de nyquist — que também serão postados junto ao plot médio.
#
# Em cada um desses três gráficos, vamos focar em observar apenas a variação máximas de um parâmetro segundo a tabela experimental acima.

# %% [markdown]
# ## <font style='font-size: 20px;'> Variação do ganho  </font> <hr style='line: 2px solid;'>

# %%
# CÓDIGO OMITIDO
# Out:
# → Informações obtidas numericamente:
#    Margem de Ganho (dB)  Margem de Fase (graus)  \
# 0                   inf               30.001566
#
#    Frequência de Crossover (Ω/seg)  Frequência de Fase Zero (Ω/seg)
# 0                              NaN                         7.803765

# %%
# CÓDIGO OMITIDO

# %% [markdown]
# Como esperado, a variação do ganho só deslocou o gráfico de ganho para cima e aumentou o plot de nyquist.

# %% [markdown]
# ## <font style='font-size: 20px;'> Variação do Coeficiente de amortecimento  </font> <hr style='line: 2px solid;'>

# %%
# CÓDIGO OMITIDO
# Out:
# → Informações obtidas numericamente:
#    Margem de Ganho (dB)  Margem de Fase (graus)  \
# 0                   inf               52.159996
#
#    Frequência de Crossover (Ω/seg)  Frequência de Fase Zero (Ω/seg)
# 0                              NaN                         6.119671

# %%
# CÓDIGO OMITIDO

# %% [markdown]
# 1. O coeficiente de amortencimento tem impacto direto no pico de ressoância, por isso podemos ver que houve um leve aumento;
# 2. Ele alterou o comportamento transiente da função, transformando ela num passa baixa

# %% [markdown]
# ## <font style='font-size: 20px;'> Variação da frequência natural amortecida  </font> <hr style='line: 2px solid;'>

# %%
# CÓDIGO OMITIDO
# Out:
# → Informações obtidas numericamente:
#    Margem de Ganho (dB)  Margem de Fase (graus)  \
# 0                   inf              135.785836
#
#    Frequência de Crossover (Ω/seg)  Frequência de Fase Zero (Ω/seg)
# 0                              NaN                         0.311859

# %%
# CÓDIGO OMITIDO

# %% [markdown]
# 1.

# %% [markdown]
# # <font style='font-size: 40px;'> QUESTÃO 4 </font> <hr style='border: 2px solid'>

# %% [markdown]
# Assumindo a 𝑮(𝒔) e o sistema de controle acima, projete os seguintes controladores, adotando as especificações:
# -  **margem de fase de $55°$**
# -  **$e_{ss}$ = 0.02**

# %% [markdown]
# ## <font style='font-size: 20px;'> a) Um controlador de avanço de fase Gcav(s). No diagrama de Bode de Gcav(s)G(s), aponte:  </font> <hr style='line: 2px solid;'>

# %% [markdown]
# > práticamente não fiz cálculos, usei cálculo numérico para produzir todos os meus resultados. Os códigos serão deixados em um arquivo a parte.

# %% [markdown]
# É impossível projetar um compensador para esses ajustes. Nesse contexto, os requisitos são multuamente exclusivos. Precisávamos de 10° de MF a mais, para tentar buscar o valor adequado ajustei $\phi_m = 13°$ — seguindo as recomendações do Castrucci (pg 380), some +3°.
#
# Esse ajuste não nos fornece uma margem adequada. A única forma de obter a margem adequada seria baixando o ganho — o que eliminaria nosso  $e_{ss} = 0.02$. Considerando que a margem de fase é um requisito de segurança mais crítico — pois define a estabilidade do comportamento do sistema — talvez fosse o caso de abrir mão dela.
#
# Mas, mesmo diminuindo o ganho, intervalo das frequências do compensador ficria ridiculamente grande visto que o alfa teria que ser muito pequeno — sinceramente não sei se isso é viável. No fim, só segui as recomendações de projeto e serão sobre elas que irei dissertar.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Função transferência, zeros e polos foram obtidos numéricamente. Código foi omitido, será deixado no arquivo de simulação.
#
# $$ G_f(s) = \frac{1.495s + 28.08}{0.05325 s^3 + 1.16 s^2 + 133.3 s + 1011}$$
#
# Zeros:
# - -18.78016958+0.j
#
# Polos:
# - -6.9285211+48.43523001j
# - -6.9285211-48.43523001j
# - -7.9325867 +0.j

# %% [markdown]
# ## <font style='font-size: 20px;'> b) Um controlador de atraso de fase Gcat(s). No diagrama de Bode de Gcav(s)G(s), aponte:  </font> <hr style='line: 2px solid;'>

# %% [markdown]
# > práticamente não fiz cálculos, usei cálculo numérico para produzir todos os meus resultados. Os códigos serão deixados em um arquivo a parte.

# %% [markdown]
# O compensador por atraso é justamente o que precisamos. Basicamente, ele irá diminuir o ganho em um intervalo específico para garantir uma margem de fase adequada. Com isso iremos conseguir manter nosso requisito de $e_{ss}$

# %% [markdown]
# ## <font style='font-size: 20px;'> c) Um controlador de atraso de fase Gcavat(s). No diagrama de Bode de Gcav(s)G(s), aponte:  </font> <hr style='line: 2px solid;'>

# %% [markdown]
# > práticamente não fiz cálculos, usei cálculo numérico para produzir todos os meus resultados. Os códigos serão deixados em um arquivo a parte.

# %% [markdown]
# ## <font style='font-size: 20px;'> d) Qual desses controladores propicia uma melhor estabilidade relativa para o sistema de controle?  </font> <hr style='line: 2px solid;'>

# %% [markdown]
# ## <font style='font-size: 20px;'> e) Qual controlador ocasiona o maior sobressinal e o maior tempo de acomodação 5% ? </font> <hr style='line: 2px solid;'>
