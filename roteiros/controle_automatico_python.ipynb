# %% [markdown]
# # <font color='yellow' style='font-size: 30px;'>Análise de resposta transitória e de regime estacionário</font> <hr style='border: 2px solid yellow;'>

# %% [markdown]
# ## <span style=color:white> O que diabos é essa tal de 'Análise'?

# %% [markdown]
# A análise consiste em pegar um sistema de controle e perturba-lo com um sinal conhecido, o que é chamado de "teste". Existem vários sinais de teste, como degrau, rampa, parábola de aceleração e impulso. A ideia é provocar um sinal desses na entrada do sistema e ver como ele se comporta. Isso é interessante porque esses sinais são conhecidos, de forma que a saída do sistema carregue alguma informação intrínseca do mesmo, a chamada "resposta característica" do sistema.
#
# É interessante testar seu sistema nas condições em que ele for projetado para operar, por exemplo:
#
# - Se as entradas de um sistema de controle são funções de tempo que variam gradualmente, então a rampa em função do tempo pode ser um bom sinal de teste;
# - Se um sistema estiver sujeito a variações bruscas de entrada, a função degrau poderá ser um bom sinal de teste;
# - Se o sistema estiver sujeito a entradas de impacto, uma função impulso poderá ser a melhor opção.
#
# #### A resposta: <hr style='line: 1px solid white;'>
#
# A resposta do sistema fica dividida entre uma ***parte transitória*** — porque se é um sistema de controle, o que se deve observar é um disturbio e logo após um retorno para um estado "estável" — e outra ***estacionária***. Dito isso, vamos ter as seguintes definições em mente:
#
# 1. Um sistema de controle está em equilíbrio se, na ausência de qualquer distúrbio ou sinal de entrada, a saída permanece no mesmo estado;
#
# 2. Um sistema de controle linear e invariante no tempo é estável se a saída sempre retorna ao estado de equilíbrio quando o sistema é submetido a uma condição inicial;
#
# 3. Um sistema de controle linear e invariante no tempo é criticamente estável se as oscilações do sinal de saída se repetirem de maneira contínua;
#
# 4. É instável se a saída divergir sem limites a partir do estado de equilíbrio quando o sistema for sujeito a uma condição inicial.
#
# #### Na prática a teoria é outra: <hr style='line: 1px solid white;'>
#
# Na verdade, os sistemas contém elementos armazenadores de energia, o que implica que eles, os sistemas, não irão responder instantaneamente os sinais de entrada. Além disso, apresentam transitórios periódicos. A constante de tempo é algo que irá influenciar totalmente essa resposta do sistema. Quanto menor a constante de tempo, mais rápida será a resposta — a constante é calculada, sempre, a partir dos elementos armazenadores de energia.
#
# Por exemplo, para um circuito RLC em série, essa constante seria dada por $$\tau = \frac{L}{R}$$
#
# **Td (tempo de atraso)**: é o tempo que a resposta leva para sair do repouso até começar a se mover.
#
# **Tr (tempo de subida)**: é o tempo que a resposta leva para ir do valor inicial até o valor final pela primeira vez.
#
# **Tp (tempo de pico)**: é o tempo que a resposta leva para atingir o valor máximo.
#
# **Mp (máximo sobressinal)**: é a porcentagem em que a resposta excede o valor final, em relação a esse valor final.
#
# **Ts (tempo de acomodação)**: é o tempo que a resposta leva para atingir um estado estacionário, ou seja, para ficar próxima do valor final e permanecer nessa região sem oscilar excessivamente.
#
# > *Geralmente é definido como o tempo que leva para a resposta estar dentro de uma faixa em torno do valor final, como por exemplo, 2% ou 5%.*

# %% [markdown]
# ## <span style=color:White> Análise para sistemas de primeira Ordem

# %% [markdown]
# <p style="text-align:center">
#     <img src="./imagens/diagrama_bloco_1ordem.png">
# </p>
#
# A função transferência deste diagrama é óbviamente dada por:
#
# $$\frac{C(s)}{R(s)} = \frac{1}{Ts+1} \tag{1}$$
#
# Nesse sentido, para saber a resposta do circuito $C(s)$, precisamos fazer com que $R(s)$ seja uma função degrau. Essa função, no domínio da frequência é dada por $\frac{1}{s}$, logo, temos:
#
# $$C(s) = \frac{1}{Ts+1}\cdot \frac{1}{s} \tag{2}$$
#
# Após a expansão das frações, teremos:
#
# $$C(s) = \frac{1}{s}-\frac{1}{s+\frac{1}{T}} \tag{3}$$
#
# Fazendo a transformada de Laplace inversa:
#
# $$c\left(t\right)=1-e^{-\frac{t}{\tau \:}} \tag{4}$$
#
#
# <p style="text-align:center">
#     <img src="./imagens/primeirograu_tempo.png">
# </p>
#
# Seguindo a mesma linha de raciocínio, temos a resposta para:
# - Rampa: $$c\left(t\right)\:=\:t\:-\:T\:+\:Te-t/T$$
# - Impulso : $$c\left(t\right)=\frac{1}{T}e^{-\frac{t}{\tau }}$$
#
# Finalmente, sabendo que função rampa é denotada por $r(t)$, degrau unitário, $u(t)$ e impulso $\delta \left(t\right)$
#
# $$ \delta \left(t\right)\:=\:\frac{du\left(t\right)}{dt}$$
# $$\:u\left(t\right)=\frac{dr\left(t\right)}{dt}$$
# $$\:\delta \:\left(t\right)=\frac{d^2r\left(t\right)}{dt^2} $$

# %% [markdown]
# ## <span style=color:White> Análise para sistemas de segunda Ordem

# %% [markdown]
# Agora, vamos focar nossas atenções em:
# - $\sigma$ : atenuação
# - $\omega_n$ : frequência natural
# - $\zeta$ : coeficiente de amortecimento
#
# Antes de mais nada, é preciso ter em mente que:
#
# > um sistema é dito de segunda ordem se possuir dois polos — e podendo ter um ou dois zeros.
#
# #### O que é um 'polo' e um 'zero'? <hr style='line: 1px solid white;'>
#
# Os zeros de uma função de transferência são os valores de s (variável complexa utilizada na representação das funções de transferência) que anulam o numerador da função. Ou seja, são as raízes do numerador da função de transferência. Geometricamente, os zeros representam os pontos onde a magnitude da resposta do sistema é nula, ou seja, onde a resposta é zero.
#
#     Isso é bastante óbvio, visto que se o numerador de uma razão tende a ser nulo, a razão tende a ser nula, pois é diretamente proporcional ao numerador. Assim, zeros são os 'lugares geométricos' que anulam a transferência de informação.
#
# Os polos, por sua vez, são os valores de s que anulam o denominador da função de transferência. Ou seja, são as raízes do denominador da função de transferência. Geometricamente, os polos representam os pontos onde a resposta do sistema cresce exponencialmente e onde o sistema pode se tornar instável.
#
#     De maneira análoga, se o denominador de qualquer razão tende a zero, isso significa que a razão em si está tendo um comportamento assintótico. Com efeito, os polos são os 'lugares geométricos' que fazem a transferência de informação 'explodir'.
#
# A localização dos polos e zeros na região do plano complexo pode fornecer informações valiosas sobre a estabilidade e o desempenho do sistema. Por exemplo:
# - Se os polos estiverem localizados no semi-plano direito do plano complexo, o sistema será instável.
# - Se os zeros estiverem próximos aos polos, o sistema pode apresentar uma resposta oscilatória e instável.
# - Se os polos estiverem localizados na parte esquerda do plano complexo e estiverem bem separados entre si, o sistema será estável e terá uma resposta suave e controlável.
#
# #### Tá, e o que isso tem a ver com essas constantes que você citou? <hr style='line: 1px solid white;'>
#
# Essas são constantes características do sistema, elas relacionam grandezas do sistema físico com esses conceitos de polos e zeros. Em outras palavras, elas nos permitem controlar a taxa de transferência de informação do sistema — o que pode ser interpretado como sua estabilidade — a partir de grandezas físicas, como resistência, capacitância, torque, constante de hooke, etc.
#
# A obtenção desses coeficientes físicos irá depender do tipo de sistema que se pretende controlar, mas de maneira geral, as regras para sistemas de segunda ordem são as seguinte:
#
# - O comportamento dinâmico do sistema de segunda ordem pode ser descrito em termos de dois parâmetros $\zeta$ e $\omega_n$, sendo que o primeiro atua sobre o segundo das formas abaixo.
# - Se $0 < \zeta < 1$, os polos de malha fechada são complexos conjugados e se situam no semiplano esquerdo do plano s. O sistema é então chamado subamortecido, e a resposta transitória é oscilatória.
# - Se $\zeta = 0$, a resposta transitória não decai.
# - Se $\zeta = 1$, o sistema é denominado criticamente amortecido; os dois polos de C(s)/R(s) são iguais.
# - Se $\zeta > 1$, o sistema é denominado superamortecido; nesse caso, os dois polos de C(s)/R(s) são reais, negativos e desiguais.

# %% [markdown]
# ## <span style=color:White> Análise para Transitório com Python

# %% [markdown]
# Geralmente, é o suficiente testar o sistema para um degrau unitário. Considerando que a resposta dependente de condições iniciais, é comum, para fins de comparação entre diferentes sistemas, manter as mesmas configurações iniciais.
#
# 1. Tempo de atraso, $t_d$
#     > trata-se do tempo requerido para que a resposta alcance metade de seu valor final pela primeira vez.
# 2. Tempo de subida, $t_r$
#     > é o tempo requerido para que a resposta passe de 10 a 90%, ou de 5% a 95%, ou de 0% a 100% do valor final. Para sistemas de segunda ordem subamortecidos, o tempo de subida de 0% a 100% é o normalmente utilizado. Para os sistemas superamortecidos, o tempo de subida de 10% a 90% é o mais comumente utilizado.
# 3. Tempo de pico, $t_p$
#     >  é o tempo para que a resposta atinja o primeiro pico de sobressinal.
# 4. Máximo sobressinal (ou apenas sobressinal), $M_p$
#     > é o valor máximo de pico da curva de resposta, medido a partir da unidade. Se o valor final da resposta em regime permanente diferir da unidade, então é comum utilizar porcentagem máxima de sobressinal, que indica diretamente a estabilidade relativa do sistema e é definida por:
#     $$ \%\:máx.\:sobressinal\:=\:\frac{c\left(t_p\right)-c\left(\infty \:\:\right)}{c\left(\infty \:\:\right)}\cdot 100\% $$
# 5. Tempo de acomodação, $t_s$
#     >  é o tempo necessário para que a curva de resposta alcance valores em uma faixa (geralmente de 2% ou 5%) em torno do valor final, aí permanecendo indefinidamente. O tempo de acomodação está relacionado à maior constante de tempo do sistema de controle. Pode-se determinar qual porcentagem deve ser utilizada no critério de erro a partir dos objetivos do projeto do sistema em questão

# %% [markdown]
# ### Vamos falar de Python <hr style='line: 1px solid white;'>

# %% [markdown]
# A principal forma de representar as funções transferência se dá através de vetores. Um vetor representa o denominador e outro o numerador. Ao calcular a função transferência, na verdade teremos que guardar um objeto do tipo *'TransferFunction'*, que utiliza vetores de numerador e denominador como inputs.
#
# Considere essa função transferência.
#
# $$\frac{C\left(s\right)}{R\left(s\right)}=\frac{2s+25}{s^2+4s+\:25}$$
#
# Após isso, você deseja aplicar um teste de resposta ao degrau unitário. Para isso, primeiro é necessário criar o vetor de tempo, o que é feito com o *'numpy.linspace()'*. Com isso, você pode chamar o método *'control.step_response()'*, que aplica um degrau unitário à uma função transferência.
#
# O resto é usado para plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ct

# Definir a função de transferência
num = [2, 25]
den = [1, 4, 25]
G = ct.TransferFunction(num, den)

# Executar a função step
t = np.linspace(0, 5, 1000)
t, y = ct.step_response(G, t)

# Plotar o gráfico
plt.plot(t, y)
plt.xlabel('Tempo (s)')
plt.ylabel('Amplitude')
plt.title('Resposta ao degrau')
plt.grid(True)
plt.show()

# %%
import numpy as np
import control
import matplotlib.pyplot as plt

# Definindo as matrizes A, B, C e D
A = np.array([[0, 1], [-25, -4]])
B = np.array([[0], [2]])
C = np.array([[2/np.sqrt(21), 25*np.sqrt(21)/(21*2+42+21*np.sqrt(21))]])
D = np.array([[0]])

# Criando o objeto sistema de espaço de estados
sys = control.StateSpace(A, B, C, D)

# Simulando a resposta ao degrau unitário
t = np.linspace(0, 5, 1000)
t, y = control.step_response(sys, T=t)

# Plotando a resposta ao degrau unitário
plt.plot(t, y)
plt.xlabel('Tempo (s)')
plt.ylabel('Saída')
plt.title('Resposta ao degrau unitário')
plt.grid()
plt.show()

# %% [markdown]
# ## <span style=color:white> Critério de Routh

# %% [markdown]
# A pergunta é : Sob quais condições um sistema se tornará instável? Se for instável, como deveríamos estabilizá-lo?
#
# > Se e somente se todos os polos de malha fechada estiverem situados no semiplano esquerdo do plano s.
#
# O critério nos diz se existem ou não raízes instáveis em uma equação polinomial, sem que seja necessário resolvê-la. Este critério de estabilidade aplica-se somente a polinômios com um número finito de termos.

# %%
import numpy as np
import matplotlib.pyplot as plt
import control

# Definir as funções de transferência G1(s), G2(s), H(s) e Gc(s)
G1 = control.TransferFunction([1], [1, 2, 1])
G2 = control.TransferFunction([1], [1, 3])
H = control.TransferFunction([1], [1])
Gc = control.TransferFunction([1], [1, 1])

# Definir a função de transferência em malha fechada G(s)
G = Gc * G1 * H / (1 + Gc * G1 * H)

# Definir o vetor de tempo de simulação
T = np.linspace(0, 10, 1000)

# Calcular a resposta ao degrau do sistema para um degrau unitário de referência
t, y = control.step_response(G, T)

# Calcular o erro estacionário para cada valor de referência R(s)
e_ss = abs(1 - y[-1])

# Calcular o tipo de sistema
system_type = control.poles(G)[0]

# Plotar o erro estacionário em função do tipo de sistema
plt.plot(system_type, e_ss, 'bo')
plt.xlabel('Tipo de sistema')
plt.ylabel('Erro estacionário')
plt.show()
# Out:
# c:\Users\Mathe\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\cbook\__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# \begin{equation}
# \frac{R(s)}{C(s)} = \frac{K_p + \frac{K_p}{T_is}}{\frac{k}{\tau s + 1}}
# \end{equation}

# %% [markdown]
# ## <span style=color:White> Efeitos das ações de controle integral e derivativo no desempenho dos sistemas

# %% [markdown]
# ## <span style=color:White> Erros estacionários em sistemas de controle com realimentação unitária

# %% [markdown]
# # <font color='yellow' style='font-size: 30px;'>Lugar das raízes</font> <hr style='border: 2px solid yellow;'>

# %% [markdown]
# suponha o seguinte polinômio característico:
#
# $$P\left(s\right)=1+k_p\frac{\left(s+\frac{1}{\frac{\tau \:\:}{2}}\right)\frac{k}{\tau }}{s\left(s+\frac{1}{\tau }\right)}$$

# %%
import numpy as np
import matplotlib.pyplot as plt
import control

kp = 2.0
tau = 1.0
k = 1.0

num = [k*kp/tau, kp*k/tau, kp*k/tau]
den = [1, 1/tau, 0]

sys = control.tf(num, den)
control.root_locus(sys)

plt.show()
